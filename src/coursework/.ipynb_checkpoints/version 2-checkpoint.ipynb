# %%
import sys, codecs, json, math, time, warnings
warnings.simplefilter( action='ignore', category=FutureWarning )

import nltk, scipy, sklearn, sklearn_crfsuite, sklearn_crfsuite.metrics, eli5
from sklearn.metrics import make_scorer
from collections import Counter
import matplotlib.pyplot as plt
from IPython.display import display    
import numpy as np

import logging
import tensorflow as tf
import absl.logging
formatter = logging.Formatter('[%(levelname)s|%(filename)s:%(lineno)s %(asctime)s] %(message)s')
absl.logging.get_absl_handler().setFormatter(formatter)
absl.logging._warn_preinit_stderr = False
logger = tf.get_logger()
logger.setLevel(logging.INFO)

# %%
#use this to stop that annoying no tabs thing :)
    # %%javascript

    // apply setting to all current CodeMirror instances
    IPython.notebook.get_cells().map(
        function(c) {  return c.code_mirror.options.indentWithTabs=true;  }
    );

    // make sure new CodeMirror instances created in the future also use this setting
    CodeMirror.defaults.indentWithTabs=true;
# Out:
#   File "<ipython-input-114-d2ad66decdbe>", line 2
#     get_ipython().run_line_magic('%javascript', '')
#     ^
# IndentationError: unexpected indent

# %%
from nltk import pos_tag

# %%
#DATE,CARDINAL, ORDINAL, NORP

max_iter = 150
#max_files = 100
display_label_subset = ["B-DATE", "I-DATE", "B-CARDINAL", "I-CARDINAL", "B-ORDINAL", "I-ORDINAL", "B-NORP", "I-NORP", "B-PERSON", "I-PERSON"]

# %%
all_ner_tags = set()

# %%
#experiment with a set of all ner tags to see all the different possible ones

#load ALL the sentences from the ontonotes dataset without splitting

#ignore the POS tags in the ontonotes dataset as we are going to use
#NLTK POS tags instead so that the training instances are the same
#as when we use with the book which will use the NLTK function to
#determine POS tags of tokens
def load_ontonotes_dataset():

	dataset_file = 'ontonotes_parsed.json'
	# load parsed ontonotes dataset
	readHandle = codecs.open( dataset_file, 'r', 'utf-8', errors = 'replace' )
	str_json = readHandle.read()
	readHandle.close()
	dict_ontonotes = json.loads( str_json )
    
	orig_list = list(dict_ontonotes.keys())
    
    #if we have specified a max number smaller than the list size then only read this many files
	#final_list = orig_list[:max_files]#orig_list if max_files > len(orig_list) else orig_list[max_files:]
    
	print("original list length:", len(orig_list))
	#print("final list length:", len(final_list))
    
	sentences = []
	i = 0
    
	for str_file in orig_list :
		print("on file number:", i)
		i += 1
		for str_sent_index in dict_ontonotes[str_file] :
            
            #BELOW, think we should use all as we are just going to work out
            #our own pos tags anyway?
            
			# ignore sents with non-PENN POS tags
			#if 'XX' in dict_ontonotes[str_file][str_sent_index]['pos'] :
			#	continue
			#if 'VERB' in dict_ontonotes[str_file][str_sent_index]['pos'] :
			#	continue
			tokens = []
			ner_tags = []
			# compute IOB tags for named entities (if any)
			ne_type_last = None
            
            #build up the list of tokens and ner tags
			for nTokenIndex in range(len(dict_ontonotes[str_file][str_sent_index]['tokens'])) :
				strToken = dict_ontonotes[str_file][str_sent_index]['tokens'][nTokenIndex]
				strPOS = dict_ontonotes[str_file][str_sent_index]['pos'][nTokenIndex]
				ne_type = None
				if 'ne' in dict_ontonotes[str_file][str_sent_index] :
					dict_ne = dict_ontonotes[str_file][str_sent_index]['ne']
					if not 'parse_error' in dict_ne :
						for str_NEIndex in dict_ne :
							if nTokenIndex in dict_ne[str_NEIndex]['tokens'] :
								ne_type = dict_ne[str_NEIndex]['type']
								break
				if ne_type != None :
					if ne_type == ne_type_last :
						strIOB = 'I-' + ne_type
					else :
						strIOB = 'B-' + ne_type
				else :
					strIOB = 'O'
                    
				all_ner_tags.add(strIOB)            
                    
				ne_type_last = ne_type
				tokens.append(strToken)
				ner_tags.append(strIOB)
				#list_entry.append( ( strToken, strIOB ) )
            
            
			skip = True
            
			for tag in ner_tags:
                display label subset contains the NER tags that we are looking for
				if tag in display_label_subset:
					skip = False
					break
            
            #this sentence does not contain any of the named entity tags
            #that we are looking for so it is useless, don't bother using it
			if skip:
				
				#continue
            
			list_entry = []
            
            #use nltk pos tags instead
			for (index, tup) in enumerate(pos_tag(tokens)):
				#print("tup is:", tup)
				list_entry.append((tup[0], tup[1], ner_tags[index]))
            #here is where we want to inser the NLTK pos tags
			sentences.append( list_entry )
	return sentences

# %%
sentences = load_ontonotes_dataset()
# Out:
# original list length: 13109
# on file number: 0
# on file number: 1
# on file number: 2
# on file number: 3
# on file number: 4
# on file number: 5
# on file number: 6
# on file number: 7
# on file number: 8
# on file number: 9
# on file number: 10
# on file number: 11
# on file number: 12
# on file number: 13
# on file number: 14
# on file number: 15
# on file number: 16
# on file number: 17
# on file number: 18
# on file number: 19
# on file number: 20
# on file number: 21
# on file number: 22
# on file number: 23
# on file number: 24
# on file number: 25
# on file number: 26
# on file number: 27
# on file number: 28
# on file number: 29
# on file number: 30
# on file number: 31
# on file number: 32
# on file number: 33
# on file number: 34
# on file number: 35
# on file number: 36
# on file number: 37
# on file number: 38
# on file number: 39
# on file number: 40
# on file number: 41
# on file number: 42
# on file number: 43
# on file number: 44
# on file number: 45
# on file number: 46
# on file number: 47
# on file number: 48
# on file number: 49
# on file number: 50
# on file number: 51
# on file number: 52
# on file number: 53
# on file number: 54
# on file number: 55
# on file number: 56
# on file number: 57
# on file number: 58
# on file number: 59
# on file number: 60
# on file number: 61
# on file number: 62
# on file number: 63
# on file number: 64
# on file number: 65
# on file number: 66
# on file number: 67
# on file number: 68
# on file number: 69
# on file number: 70
# on file number: 71
# on file number: 72
# on file number: 73
# on file number: 74
# on file number: 75
# on file number: 76
# on file number: 77
# on file number: 78
# on file number: 79
# on file number: 80
# on file number: 81
# on file number: 82
# on file number: 83
# on file number: 84
# on file number: 85
# on file number: 86
# on file number: 87
# on file number: 88
# on file number: 89
# on file number: 90
# on file number: 91
# on file number: 92
# on file number: 93
# on file number: 94
# on file number: 95
# on file number: 96
# on file number: 97
# on file number: 98
# on file number: 99
# on file number: 100
# on file number: 101
# on file number: 102
# on file number: 103
# on file number: 104
# on file number: 105
# on file number: 106
# on file number: 107
# on file number: 108
# on file number: 109
# on file number: 110
# on file number: 111
# on file number: 112
# on file number: 113
# on file number: 114
# on file number: 115
# on file number: 116
# on file number: 117
# on file number: 118
# on file number: 119
# on file number: 120
# on file number: 121
# on file number: 122
# on file number: 123
# on file number: 124
# on file number: 125
# on file number: 126
# on file number: 127
# on file number: 128
# on file number: 129
# on file number: 130
# on file number: 131
# on file number: 132
# on file number: 133
# on file number: 134
# on file number: 135
# on file number: 136
# on file number: 137
# on file number: 138
# on file number: 139
# on file number: 140
# on file number: 141
# on file number: 142
# on file number: 143
# on file number: 144
# on file number: 145
# on file number: 146
# on file number: 147
# on file number: 148
# on file number: 149
# on file number: 150
# on file number: 151
# on file number: 152
# on file number: 153
# on file number: 154
# on file number: 155
# on file number: 156
# on file number: 157
# on file number: 158
# on file number: 159
# on file number: 160
# on file number: 161
# on file number: 162
# on file number: 163
# on file number: 164
# on file number: 165
# on file number: 166
# on file number: 167
# on file number: 168
# on file number: 169
# on file number: 170
# on file number: 171
# on file number: 172
# on file number: 173
# on file number: 174
# on file number: 175
# on file number: 176
# on file number: 177
# on file number: 178
# on file number: 179
# on file number: 180
# on file number: 181
# on file number: 182
# on file number: 183
# on file number: 184
# on file number: 185
# on file number: 186
# on file number: 187
# on file number: 188
# on file number: 189
# on file number: 190
# on file number: 191
# on file number: 192
# on file number: 193
# on file number: 194
# on file number: 195
# on file number: 196
# on file number: 197
# on file number: 198
# on file number: 199
# on file number: 200
# on file number: 201
# on file number: 202
# on file number: 203
# on file number: 204
# on file number: 205
# on file number: 206
# on file number: 207
# on file number: 208
# on file number: 209
# on file number: 210
# on file number: 211
# on file number: 212
# on file number: 213
# on file number: 214
# on file number: 215
# on file number: 216
# on file number: 217
# on file number: 218
# on file number: 219
# on file number: 220
# on file number: 221
# on file number: 222
# on file number: 223
# on file number: 224
# on file number: 225
# on file number: 226
# on file number: 227
# on file number: 228
# on file number: 229
# on file number: 230
# on file number: 231
# on file number: 232
# on file number: 233
# on file number: 234
# on file number: 235
# on file number: 236
# on file number: 237
# on file number: 238
# on file number: 239
# on file number: 240
# on file number: 241
# on file number: 242
# on file number: 243
# on file number: 244
# on file number: 245
# on file number: 246
# on file number: 247
# on file number: 248
# on file number: 249
# on file number: 250
# on file number: 251
# on file number: 252
# on file number: 253
# on file number: 254
# on file number: 255
# on file number: 256
# on file number: 257
# on file number: 258
# on file number: 259
# on file number: 260
# on file number: 261
# on file number: 262
# on file number: 263
# on file number: 264
# on file number: 265
# on file number: 266
# on file number: 267
# on file number: 268
# on file number: 269
# on file number: 270
# on file number: 271
# on file number: 272
# on file number: 273
# on file number: 274
# on file number: 275
# on file number: 276
# on file number: 277
# on file number: 278
# on file number: 279
# on file number: 280
# on file number: 281
# on file number: 282
# on file number: 283
# on file number: 284
# on file number: 285
# on file number: 286
# on file number: 287
# on file number: 288
# on file number: 289
# on file number: 290
# on file number: 291
# on file number: 292
# on file number: 293
# on file number: 294
# on file number: 295
# on file number: 296
# on file number: 297
# on file number: 298
# on file number: 299
# on file number: 300
# on file number: 301
# on file number: 302
# on file number: 303
# on file number: 304
# on file number: 305
# on file number: 306
# on file number: 307
# on file number: 308
# on file number: 309
# on file number: 310
# on file number: 311
# on file number: 312
# on file number: 313
# on file number: 314
# on file number: 315
# on file number: 316
# on file number: 317
# on file number: 318
# on file number: 319
# on file number: 320
# on file number: 321
# on file number: 322
# on file number: 323
# on file number: 324
# on file number: 325
# on file number: 326
# on file number: 327
# on file number: 328
# on file number: 329
# on file number: 330
# on file number: 331
# on file number: 332
# on file number: 333
# on file number: 334
# on file number: 335
# on file number: 336
# on file number: 337
# on file number: 338
# on file number: 339
# on file number: 340
# on file number: 341
# on file number: 342
# on file number: 343
# on file number: 344
# on file number: 345
# on file number: 346
# on file number: 347
# on file number: 348
# on file number: 349
# on file number: 350
# on file number: 351
# on file number: 352
# on file number: 353
# on file number: 354
# on file number: 355
# on file number: 356
# on file number: 357
# on file number: 358
# on file number: 359
# on file number: 360
# on file number: 361
# on file number: 362
# on file number: 363
# on file number: 364
# on file number: 365
# on file number: 366
# on file number: 367
# on file number: 368
# on file number: 369
# on file number: 370
# on file number: 371
# on file number: 372
# on file number: 373
# on file number: 374
# on file number: 375
# on file number: 376
# on file number: 377
# on file number: 378
# on file number: 379
# on file number: 380
# on file number: 381
# on file number: 382
# on file number: 383
# on file number: 384
# on file number: 385
# on file number: 386
# on file number: 387
# on file number: 388
# on file number: 389
# on file number: 390
# on file number: 391
# on file number: 392
# on file number: 393
# on file number: 394
# on file number: 395
# on file number: 396
# on file number: 397
# on file number: 398
# on file number: 399
# on file number: 400
# on file number: 401
# on file number: 402
# on file number: 403
# on file number: 404
# on file number: 405
# on file number: 406
# on file number: 407
# on file number: 408
# on file number: 409
# on file number: 410
# on file number: 411
# on file number: 412
# on file number: 413
# on file number: 414
# on file number: 415
# on file number: 416
# on file number: 417
# on file number: 418
# on file number: 419
# on file number: 420
# on file number: 421
# on file number: 422
# on file number: 423
# on file number: 424
# on file number: 425
# on file number: 426
# on file number: 427
# on file number: 428
# on file number: 429
# on file number: 430
# on file number: 431
# on file number: 432
# on file number: 433
# on file number: 434
# on file number: 435
# on file number: 436
# on file number: 437
# on file number: 438
# on file number: 439
# on file number: 440
# on file number: 441
# on file number: 442
# on file number: 443
# on file number: 444
# on file number: 445
# on file number: 446
# on file number: 447
# on file number: 448
# on file number: 449
# on file number: 450
# on file number: 451
# on file number: 452
# on file number: 453
# on file number: 454
# on file number: 455
# on file number: 456
# on file number: 457
# on file number: 458
# on file number: 459
# on file number: 460
# on file number: 461
# on file number: 462
# on file number: 463
# on file number: 464
# on file number: 465
# on file number: 466
# on file number: 467
# on file number: 468
# on file number: 469
# on file number: 470
# on file number: 471
# on file number: 472
# on file number: 473
# on file number: 474
# on file number: 475
# on file number: 476
# on file number: 477
# on file number: 478
# on file number: 479
# on file number: 480
# on file number: 481
# on file number: 482
# on file number: 483
# on file number: 484
# on file number: 485
# on file number: 486
# on file number: 487
# on file number: 488
# on file number: 489
# on file number: 490
# on file number: 491
# on file number: 492
# on file number: 493
# on file number: 494
# on file number: 495
# on file number: 496
# on file number: 497
# on file number: 498
# on file number: 499
# on file number: 500
# on file number: 501
# on file number: 502
# on file number: 503
# on file number: 504
# on file number: 505
# on file number: 506
# on file number: 507
# on file number: 508
# on file number: 509
# on file number: 510
# on file number: 511
# on file number: 512
# on file number: 513
# on file number: 514
# on file number: 515
# on file number: 516
# on file number: 517
# on file number: 518
# on file number: 519
# on file number: 520
# on file number: 521
# on file number: 522
# on file number: 523
# on file number: 524
# on file number: 525
# on file number: 526
# on file number: 527
# on file number: 528
# on file number: 529
# on file number: 530
# on file number: 531
# on file number: 532
# on file number: 533
# on file number: 534
# on file number: 535
# on file number: 536
# on file number: 537
# on file number: 538
# on file number: 539
# on file number: 540
# on file number: 541
# on file number: 542
# on file number: 543
# on file number: 544
# on file number: 545
# on file number: 546
# on file number: 547
# on file number: 548
# on file number: 549
# on file number: 550
# on file number: 551
# on file number: 552
# on file number: 553
# on file number: 554
# on file number: 555
# on file number: 556
# on file number: 557
# on file number: 558
# on file number: 559
# on file number: 560
# on file number: 561
# on file number: 562
# on file number: 563
# on file number: 564
# on file number: 565
# on file number: 566
# on file number: 567
# on file number: 568
# on file number: 569
# on file number: 570
# on file number: 571
# on file number: 572
# on file number: 573
# on file number: 574
# on file number: 575
# on file number: 576
# on file number: 577
# on file number: 578
# on file number: 579
# on file number: 580
# on file number: 581
# on file number: 582
# on file number: 583
# on file number: 584
# on file number: 585
# on file number: 586
# on file number: 587
# on file number: 588
# on file number: 589
# on file number: 590
# on file number: 591
# on file number: 592
# on file number: 593
# on file number: 594
# on file number: 595
# on file number: 596
# on file number: 597
# on file number: 598
# on file number: 599
# on file number: 600
# on file number: 601
# on file number: 602
# on file number: 603
# on file number: 604
# on file number: 605
# on file number: 606
# on file number: 607
# on file number: 608
# on file number: 609
# on file number: 610
# on file number: 611
# on file number: 612
# on file number: 613
# on file number: 614
# on file number: 615
# on file number: 616
# on file number: 617
# on file number: 618
# on file number: 619
# on file number: 620
# on file number: 621
# on file number: 622
# on file number: 623
# on file number: 624
# on file number: 625
# on file number: 626
# on file number: 627
# on file number: 628
# on file number: 629
# on file number: 630
# on file number: 631
# on file number: 632
# on file number: 633
# on file number: 634
# on file number: 635
# on file number: 636
# on file number: 637
# on file number: 638
# on file number: 639
# on file number: 640
# on file number: 641
# on file number: 642
# on file number: 643
# on file number: 644
# on file number: 645
# on file number: 646
# on file number: 647
# on file number: 648
# on file number: 649
# on file number: 650
# on file number: 651
# on file number: 652
# on file number: 653
# on file number: 654
# on file number: 655
# on file number: 656
# on file number: 657
# on file number: 658
# on file number: 659
# on file number: 660
# on file number: 661
# on file number: 662
# on file number: 663
# on file number: 664
# on file number: 665
# on file number: 666
# on file number: 667
# on file number: 668
# on file number: 669
# on file number: 670
# on file number: 671
# on file number: 672
# on file number: 673
# on file number: 674
# on file number: 675
# on file number: 676
# on file number: 677
# on file number: 678
# on file number: 679
# on file number: 680
# on file number: 681
# on file number: 682
# on file number: 683
# on file number: 684
# on file number: 685
# on file number: 686
# on file number: 687
# on file number: 688
# on file number: 689
# on file number: 690
# on file number: 691
# on file number: 692
# on file number: 693
# on file number: 694
# on file number: 695
# on file number: 696
# on file number: 697
# on file number: 698
# on file number: 699
# on file number: 700
# on file number: 701
# on file number: 702
# on file number: 703
# on file number: 704
# on file number: 705
# on file number: 706
# on file number: 707
# on file number: 708
# on file number: 709
# on file number: 710
# on file number: 711
# on file number: 712
# on file number: 713
# on file number: 714
# on file number: 715
# on file number: 716
# on file number: 717
# on file number: 718
# on file number: 719
# on file number: 720
# on file number: 721
# on file number: 722
# on file number: 723
# on file number: 724
# on file number: 725
# on file number: 726
# on file number: 727
# on file number: 728
# on file number: 729
# on file number: 730
# on file number: 731
# on file number: 732
# on file number: 733
# on file number: 734
# on file number: 735
# on file number: 736
# on file number: 737
# on file number: 738
# on file number: 739
# on file number: 740
# on file number: 741
# on file number: 742
# on file number: 743
# on file number: 744
# on file number: 745
# on file number: 746
# on file number: 747
# on file number: 748
# on file number: 749
# on file number: 750
# on file number: 751
# on file number: 752
# on file number: 753
# on file number: 754
# on file number: 755
# on file number: 756
# on file number: 757
# on file number: 758
# on file number: 759
# on file number: 760
# on file number: 761
# on file number: 762
# on file number: 763
# on file number: 764
# on file number: 765
# on file number: 766
# on file number: 767
# on file number: 768
# on file number: 769
# on file number: 770
# on file number: 771
# on file number: 772
# on file number: 773
# on file number: 774
# on file number: 775
# on file number: 776
# on file number: 777
# on file number: 778
# on file number: 779
# on file number: 780
# on file number: 781
# on file number: 782
# on file number: 783
# on file number: 784
# on file number: 785
# on file number: 786
# on file number: 787
# on file number: 788
# on file number: 789
# on file number: 790
# on file number: 791
# on file number: 792
# on file number: 793
# on file number: 794
# on file number: 795
# on file number: 796
# on file number: 797
# on file number: 798
# on file number: 799
# on file number: 800
# on file number: 801
# on file number: 802
# on file number: 803
# on file number: 804
# on file number: 805
# on file number: 806
# on file number: 807
# on file number: 808
# on file number: 809
# on file number: 810
# on file number: 811
# on file number: 812
# on file number: 813
# on file number: 814
# on file number: 815
# on file number: 816
# on file number: 817
# on file number: 818
# on file number: 819
# on file number: 820
# on file number: 821
# on file number: 822
# on file number: 823
# on file number: 824
# on file number: 825
# on file number: 826
# on file number: 827
# on file number: 828
# on file number: 829
# on file number: 830
# on file number: 831
# on file number: 832
# on file number: 833
# on file number: 834
# on file number: 835
# on file number: 836
# on file number: 837
# on file number: 838
# on file number: 839
# on file number: 840
# on file number: 841
# on file number: 842
# on file number: 843
# on file number: 844
# on file number: 845
# on file number: 846
# on file number: 847
# on file number: 848
# on file number: 849
# on file number: 850
# on file number: 851
# on file number: 852
# on file number: 853
# on file number: 854
# on file number: 855
# on file number: 856
# on file number: 857
# on file number: 858
# on file number: 859
# on file number: 860
# on file number: 861
# on file number: 862
# on file number: 863
# on file number: 864
# on file number: 865
# on file number: 866
# on file number: 867
# on file number: 868
# on file number: 869
# on file number: 870
# on file number: 871
# on file number: 872
# on file number: 873
# on file number: 874
# on file number: 875
# on file number: 876
# on file number: 877
# on file number: 878
# on file number: 879
# on file number: 880
# on file number: 881
# on file number: 882
# on file number: 883
# on file number: 884
# on file number: 885
# on file number: 886
# on file number: 887
# on file number: 888
# on file number: 889
# on file number: 890
# on file number: 891
# on file number: 892
# on file number: 893
# on file number: 894
# on file number: 895
# on file number: 896
# on file number: 897
# on file number: 898
# on file number: 899
# on file number: 900
# on file number: 901
# on file number: 902
# on file number: 903
# on file number: 904
# on file number: 905
# on file number: 906
# on file number: 907
# on file number: 908
# on file number: 909
# on file number: 910
# on file number: 911
# on file number: 912
# on file number: 913
# on file number: 914
# on file number: 915
# on file number: 916
# on file number: 917
# on file number: 918
# on file number: 919
# on file number: 920
# on file number: 921
# on file number: 922
# on file number: 923
# on file number: 924
# on file number: 925
# on file number: 926
# on file number: 927
# on file number: 928
# on file number: 929
# on file number: 930
# on file number: 931
# on file number: 932
# on file number: 933
# on file number: 934
# on file number: 935
# on file number: 936
# on file number: 937
# on file number: 938
# on file number: 939
# on file number: 940
# on file number: 941
# on file number: 942
# on file number: 943
# on file number: 944
# on file number: 945
# on file number: 946
# on file number: 947
# on file number: 948
# on file number: 949
# on file number: 950
# on file number: 951
# on file number: 952
# on file number: 953
# on file number: 954
# on file number: 955
# on file number: 956
# on file number: 957
# on file number: 958
# on file number: 959
# on file number: 960
# on file number: 961
# on file number: 962
# on file number: 963
# on file number: 964
# on file number: 965
# on file number: 966
# on file number: 967
# on file number: 968
# on file number: 969
# on file number: 970
# on file number: 971
# on file number: 972
# on file number: 973
# on file number: 974
# on file number: 975
# on file number: 976
# on file number: 977
# on file number: 978
# on file number: 979
# on file number: 980
# on file number: 981
# on file number: 982
# on file number: 983
# on file number: 984
# on file number: 985
# on file number: 986
# on file number: 987
# on file number: 988
# on file number: 989
# on file number: 990
# on file number: 991
# on file number: 992
# on file number: 993
# on file number: 994
# on file number: 995
# on file number: 996
# on file number: 997
# on file number: 998
# on file number: 999
# on file number: 1000
# on file number: 1001
# on file number: 1002
# on file number: 1003
# on file number: 1004
# on file number: 1005
# on file number: 1006
# on file number: 1007
# on file number: 1008
# on file number: 1009
# on file number: 1010
# on file number: 1011
# on file number: 1012
# on file number: 1013
# on file number: 1014
# on file number: 1015
# on file number: 1016
# on file number: 1017
# on file number: 1018
# on file number: 1019
# on file number: 1020
# on file number: 1021
# on file number: 1022
# on file number: 1023
# on file number: 1024
# on file number: 1025
# on file number: 1026
# on file number: 1027
# on file number: 1028
# on file number: 1029
# on file number: 1030
# on file number: 1031
# on file number: 1032
# on file number: 1033
# on file number: 1034
# on file number: 1035
# on file number: 1036
# on file number: 1037
# on file number: 1038
# on file number: 1039
# on file number: 1040
# on file number: 1041
# on file number: 1042
# on file number: 1043
# on file number: 1044
# on file number: 1045
# on file number: 1046
# on file number: 1047
# on file number: 1048
# on file number: 1049
# on file number: 1050
# on file number: 1051
# on file number: 1052
# on file number: 1053
# on file number: 1054
# on file number: 1055
# on file number: 1056
# on file number: 1057
# on file number: 1058
# on file number: 1059
# on file number: 1060
# on file number: 1061
# on file number: 1062
# on file number: 1063
# on file number: 1064
# on file number: 1065
# on file number: 1066
# on file number: 1067
# on file number: 1068
# on file number: 1069
# on file number: 1070
# on file number: 1071
# on file number: 1072
# on file number: 1073
# on file number: 1074
# on file number: 1075
# on file number: 1076
# on file number: 1077
# on file number: 1078
# on file number: 1079
# on file number: 1080
# on file number: 1081
# on file number: 1082
# on file number: 1083
# on file number: 1084
# on file number: 1085
# on file number: 1086
# on file number: 1087
# on file number: 1088
# on file number: 1089
# on file number: 1090
# on file number: 1091
# on file number: 1092
# on file number: 1093
# on file number: 1094
# on file number: 1095
# on file number: 1096
# on file number: 1097
# on file number: 1098
# on file number: 1099
# on file number: 1100
# on file number: 1101
# on file number: 1102
# on file number: 1103
# on file number: 1104
# on file number: 1105
# on file number: 1106
# on file number: 1107
# on file number: 1108
# on file number: 1109
# on file number: 1110
# on file number: 1111
# on file number: 1112
# on file number: 1113
# on file number: 1114
# on file number: 1115
# on file number: 1116
# on file number: 1117
# on file number: 1118
# on file number: 1119
# on file number: 1120
# on file number: 1121
# on file number: 1122
# on file number: 1123
# on file number: 1124
# on file number: 1125
# on file number: 1126
# on file number: 1127
# on file number: 1128
# on file number: 1129
# on file number: 1130
# on file number: 1131
# on file number: 1132
# on file number: 1133
# on file number: 1134
# on file number: 1135
# on file number: 1136
# on file number: 1137
# on file number: 1138
# on file number: 1139
# on file number: 1140
# on file number: 1141
# on file number: 1142
# on file number: 1143
# on file number: 1144
# on file number: 1145
# on file number: 1146
# on file number: 1147
# on file number: 1148
# on file number: 1149
# on file number: 1150
# on file number: 1151
# on file number: 1152
# on file number: 1153
# on file number: 1154
# on file number: 1155
# on file number: 1156
# on file number: 1157
# on file number: 1158
# on file number: 1159
# on file number: 1160
# on file number: 1161
# on file number: 1162
# on file number: 1163
# on file number: 1164
# on file number: 1165
# on file number: 1166
# on file number: 1167
# on file number: 1168
# on file number: 1169
# on file number: 1170
# on file number: 1171
# on file number: 1172
# on file number: 1173
# on file number: 1174
# on file number: 1175
# on file number: 1176
# on file number: 1177
# on file number: 1178
# on file number: 1179
# on file number: 1180
# on file number: 1181
# on file number: 1182
# on file number: 1183
# on file number: 1184
# on file number: 1185
# on file number: 1186
# on file number: 1187
# on file number: 1188
# on file number: 1189
# on file number: 1190
# on file number: 1191
# on file number: 1192
# on file number: 1193
# on file number: 1194
# on file number: 1195
# on file number: 1196
# on file number: 1197
# on file number: 1198
# on file number: 1199
# on file number: 1200
# on file number: 1201
# on file number: 1202
# on file number: 1203
# on file number: 1204
# on file number: 1205
# on file number: 1206
# on file number: 1207
# on file number: 1208
# on file number: 1209
# on file number: 1210
# on file number: 1211
# on file number: 1212
# on file number: 1213
# on file number: 1214
# on file number: 1215
# on file number: 1216
# on file number: 1217
# on file number: 1218
# on file number: 1219
# on file number: 1220
# on file number: 1221
# on file number: 1222
# on file number: 1223
# on file number: 1224
# on file number: 1225
# on file number: 1226
# on file number: 1227
# on file number: 1228
# on file number: 1229
# on file number: 1230
# on file number: 1231
# on file number: 1232
# on file number: 1233
# on file number: 1234
# on file number: 1235
# on file number: 1236
# on file number: 1237
# on file number: 1238
# on file number: 1239
# on file number: 1240
# on file number: 1241
# on file number: 1242
# on file number: 1243
# on file number: 1244
# on file number: 1245
# on file number: 1246
# on file number: 1247
# on file number: 1248
# on file number: 1249
# on file number: 1250
# on file number: 1251
# on file number: 1252
# on file number: 1253
# on file number: 1254
# on file number: 1255
# on file number: 1256
# on file number: 1257
# on file number: 1258
# on file number: 1259
# on file number: 1260
# on file number: 1261
# on file number: 1262
# on file number: 1263
# on file number: 1264
# on file number: 1265
# on file number: 1266
# on file number: 1267
# on file number: 1268
# on file number: 1269
# on file number: 1270
# on file number: 1271
# on file number: 1272
# on file number: 1273
# on file number: 1274
# on file number: 1275
# on file number: 1276
# on file number: 1277
# on file number: 1278
# on file number: 1279
# on file number: 1280
# on file number: 1281
# on file number: 1282
# on file number: 1283
# on file number: 1284
# on file number: 1285
# on file number: 1286
# on file number: 1287
# on file number: 1288
# on file number: 1289
# on file number: 1290
# on file number: 1291
# on file number: 1292
# on file number: 1293
# on file number: 1294
# on file number: 1295
# on file number: 1296
# on file number: 1297
# on file number: 1298
# on file number: 1299
# on file number: 1300
# on file number: 1301
# on file number: 1302
# on file number: 1303
# on file number: 1304
# on file number: 1305
# on file number: 1306
# on file number: 1307
# on file number: 1308
# on file number: 1309
# on file number: 1310
# on file number: 1311
# on file number: 1312
# on file number: 1313
# on file number: 1314
# on file number: 1315
# on file number: 1316
# on file number: 1317
# on file number: 1318
# on file number: 1319
# on file number: 1320
# on file number: 1321
# on file number: 1322
# on file number: 1323
# on file number: 1324
# on file number: 1325
# on file number: 1326
# on file number: 1327
# on file number: 1328
# on file number: 1329
# on file number: 1330
# on file number: 1331
# on file number: 1332
# on file number: 1333
# on file number: 1334
# on file number: 1335
# on file number: 1336
# on file number: 1337
# on file number: 1338
# on file number: 1339
# on file number: 1340
# on file number: 1341
# on file number: 1342
# on file number: 1343
# on file number: 1344
# on file number: 1345
# on file number: 1346
# on file number: 1347
# on file number: 1348
# on file number: 1349
# on file number: 1350
# on file number: 1351
# on file number: 1352
# on file number: 1353
# on file number: 1354
# on file number: 1355
# on file number: 1356
# on file number: 1357
# on file number: 1358
# on file number: 1359
# on file number: 1360
# on file number: 1361
# on file number: 1362
# on file number: 1363
# on file number: 1364
# on file number: 1365
# on file number: 1366
# on file number: 1367
# on file number: 1368
# on file number: 1369
# on file number: 1370
# on file number: 1371
# on file number: 1372
# on file number: 1373
# on file number: 1374
# on file number: 1375
# on file number: 1376
# on file number: 1377
# on file number: 1378
# on file number: 1379
# on file number: 1380
# on file number: 1381
# on file number: 1382
# on file number: 1383
# on file number: 1384
# on file number: 1385
# on file number: 1386
# on file number: 1387
# on file number: 1388
# on file number: 1389
# on file number: 1390
# on file number: 1391
# on file number: 1392
# on file number: 1393
# on file number: 1394
# on file number: 1395
# on file number: 1396
# on file number: 1397
# on file number: 1398
# on file number: 1399
# on file number: 1400
# on file number: 1401
# on file number: 1402
# on file number: 1403
# on file number: 1404
# on file number: 1405
# on file number: 1406
# on file number: 1407
# on file number: 1408
# on file number: 1409
# on file number: 1410
# on file number: 1411
# on file number: 1412
# on file number: 1413
# on file number: 1414
# on file number: 1415
# on file number: 1416
# on file number: 1417
# on file number: 1418
# on file number: 1419
# on file number: 1420
# on file number: 1421
# on file number: 1422
# on file number: 1423
# on file number: 1424
# on file number: 1425
# on file number: 1426
# on file number: 1427
# on file number: 1428
# on file number: 1429
# on file number: 1430
# on file number: 1431
# on file number: 1432
# on file number: 1433
# on file number: 1434
# on file number: 1435
# on file number: 1436
# on file number: 1437
# on file number: 1438
# on file number: 1439
# on file number: 1440
# on file number: 1441
# on file number: 1442
# on file number: 1443
# on file number: 1444
# on file number: 1445
# on file number: 1446
# on file number: 1447
# on file number: 1448
# on file number: 1449
# on file number: 1450
# on file number: 1451
# on file number: 1452
# on file number: 1453
# on file number: 1454
# on file number: 1455
# on file number: 1456
# on file number: 1457
# on file number: 1458
# on file number: 1459
# on file number: 1460
# on file number: 1461
# on file number: 1462
# on file number: 1463
# on file number: 1464
# on file number: 1465
# on file number: 1466
# on file number: 1467
# on file number: 1468
# on file number: 1469
# on file number: 1470
# on file number: 1471
# on file number: 1472
# on file number: 1473
# on file number: 1474
# on file number: 1475
# on file number: 1476
# on file number: 1477
# on file number: 1478
# on file number: 1479
# on file number: 1480
# on file number: 1481
# on file number: 1482
# on file number: 1483
# on file number: 1484
# on file number: 1485
# on file number: 1486
# on file number: 1487
# on file number: 1488
# on file number: 1489
# on file number: 1490
# on file number: 1491
# on file number: 1492
# on file number: 1493
# on file number: 1494
# on file number: 1495
# on file number: 1496
# on file number: 1497
# on file number: 1498
# on file number: 1499
# on file number: 1500
# on file number: 1501
# on file number: 1502
# on file number: 1503
# on file number: 1504
# on file number: 1505
# on file number: 1506
# on file number: 1507
# on file number: 1508
# on file number: 1509
# on file number: 1510
# on file number: 1511
# on file number: 1512
# on file number: 1513
# on file number: 1514
# on file number: 1515
# on file number: 1516
# on file number: 1517
# on file number: 1518
# on file number: 1519
# on file number: 1520
# on file number: 1521
# on file number: 1522
# on file number: 1523
# on file number: 1524
# on file number: 1525
# on file number: 1526
# on file number: 1527
# on file number: 1528
# on file number: 1529
# on file number: 1530
# on file number: 1531
# on file number: 1532
# on file number: 1533
# on file number: 1534
# on file number: 1535
# on file number: 1536
# on file number: 1537
# on file number: 1538
# on file number: 1539
# on file number: 1540
# on file number: 1541
# on file number: 1542
# on file number: 1543
# on file number: 1544
# on file number: 1545
# on file number: 1546
# on file number: 1547
# on file number: 1548
# on file number: 1549
# on file number: 1550
# on file number: 1551
# on file number: 1552
# on file number: 1553
# on file number: 1554
# on file number: 1555
# on file number: 1556
# on file number: 1557
# on file number: 1558
# on file number: 1559
# on file number: 1560
# on file number: 1561
# on file number: 1562
# on file number: 1563
# on file number: 1564
# on file number: 1565
# on file number: 1566
# on file number: 1567
# on file number: 1568
# on file number: 1569
# on file number: 1570
# on file number: 1571
# on file number: 1572
# on file number: 1573
# on file number: 1574
# on file number: 1575
# on file number: 1576
# on file number: 1577
# on file number: 1578
# on file number: 1579
# on file number: 1580
# on file number: 1581
# on file number: 1582
# on file number: 1583
# on file number: 1584
# on file number: 1585
# on file number: 1586
# on file number: 1587
# on file number: 1588
# on file number: 1589
# on file number: 1590
# on file number: 1591
# on file number: 1592
# on file number: 1593
# on file number: 1594
# on file number: 1595
# on file number: 1596
# on file number: 1597
# on file number: 1598
# on file number: 1599
# on file number: 1600
# on file number: 1601
# on file number: 1602
# on file number: 1603
# on file number: 1604
# on file number: 1605
# on file number: 1606
# on file number: 1607
# on file number: 1608
# on file number: 1609
# on file number: 1610
# on file number: 1611
# on file number: 1612
# on file number: 1613
# on file number: 1614
# on file number: 1615
# on file number: 1616
# on file number: 1617
# on file number: 1618
# on file number: 1619
# on file number: 1620
# on file number: 1621
# on file number: 1622
# on file number: 1623
# on file number: 1624
# on file number: 1625
# on file number: 1626
# on file number: 1627
# on file number: 1628
# on file number: 1629
# on file number: 1630
# on file number: 1631
# on file number: 1632
# on file number: 1633
# on file number: 1634
# on file number: 1635
# on file number: 1636
# on file number: 1637
# on file number: 1638
# on file number: 1639
# on file number: 1640
# on file number: 1641
# on file number: 1642
# on file number: 1643
# on file number: 1644
# on file number: 1645
# on file number: 1646
# on file number: 1647
# on file number: 1648
# on file number: 1649
# on file number: 1650
# on file number: 1651
# on file number: 1652
# on file number: 1653
# on file number: 1654
# on file number: 1655
# on file number: 1656
# on file number: 1657
# on file number: 1658
# on file number: 1659
# on file number: 1660
# on file number: 1661
# on file number: 1662
# on file number: 1663
# on file number: 1664
# on file number: 1665
# on file number: 1666
# on file number: 1667
# on file number: 1668
# on file number: 1669
# on file number: 1670
# on file number: 1671
# on file number: 1672
# on file number: 1673
# on file number: 1674
# on file number: 1675
# on file number: 1676
# on file number: 1677
# on file number: 1678
# on file number: 1679
# on file number: 1680
# on file number: 1681
# on file number: 1682
# on file number: 1683
# on file number: 1684
# on file number: 1685
# on file number: 1686
# on file number: 1687
# on file number: 1688
# on file number: 1689
# on file number: 1690
# on file number: 1691
# on file number: 1692
# on file number: 1693
# on file number: 1694
# on file number: 1695
# on file number: 1696
# on file number: 1697
# on file number: 1698
# on file number: 1699
# on file number: 1700
# on file number: 1701
# on file number: 1702
# on file number: 1703
# on file number: 1704
# on file number: 1705
# on file number: 1706
# on file number: 1707
# on file number: 1708
# on file number: 1709
# on file number: 1710
# on file number: 1711
# on file number: 1712
# on file number: 1713
# on file number: 1714
# on file number: 1715
# on file number: 1716
# on file number: 1717
# on file number: 1718
# on file number: 1719
# on file number: 1720
# on file number: 1721
# on file number: 1722
# on file number: 1723
# on file number: 1724
# on file number: 1725
# on file number: 1726
# on file number: 1727
# on file number: 1728
# on file number: 1729
# on file number: 1730
# on file number: 1731
# on file number: 1732
# on file number: 1733
# on file number: 1734
# on file number: 1735
# on file number: 1736
# on file number: 1737
# on file number: 1738
# on file number: 1739
# on file number: 1740
# on file number: 1741
# on file number: 1742
# on file number: 1743
# on file number: 1744
# on file number: 1745
# on file number: 1746
# on file number: 1747
# on file number: 1748
# on file number: 1749
# on file number: 1750
# on file number: 1751
# on file number: 1752
# on file number: 1753
# on file number: 1754
# on file number: 1755
# on file number: 1756
# on file number: 1757
# on file number: 1758
# on file number: 1759
# on file number: 1760
# on file number: 1761
# on file number: 1762
# on file number: 1763
# on file number: 1764
# on file number: 1765
# on file number: 1766
# on file number: 1767
# on file number: 1768
# on file number: 1769
# on file number: 1770
# on file number: 1771
# on file number: 1772
# on file number: 1773
# on file number: 1774
# on file number: 1775
# on file number: 1776
# on file number: 1777
# on file number: 1778
# on file number: 1779
# on file number: 1780
# on file number: 1781
# on file number: 1782
# on file number: 1783
# on file number: 1784
# on file number: 1785
# on file number: 1786
# on file number: 1787
# on file number: 1788
# on file number: 1789
# on file number: 1790
# on file number: 1791
# on file number: 1792
# on file number: 1793
# on file number: 1794
# on file number: 1795
# on file number: 1796
# on file number: 1797
# on file number: 1798
# on file number: 1799
# on file number: 1800
# on file number: 1801
# on file number: 1802
# on file number: 1803
# on file number: 1804
# on file number: 1805
# on file number: 1806
# on file number: 1807
# on file number: 1808
# on file number: 1809
# on file number: 1810
# on file number: 1811
# on file number: 1812
# on file number: 1813
# on file number: 1814
# on file number: 1815
# on file number: 1816
# on file number: 1817
# on file number: 1818
# on file number: 1819
# on file number: 1820
# on file number: 1821
# on file number: 1822
# on file number: 1823
# on file number: 1824
# on file number: 1825
# on file number: 1826
# on file number: 1827
# on file number: 1828
# on file number: 1829
# on file number: 1830
# on file number: 1831
# on file number: 1832
# on file number: 1833
# on file number: 1834
# on file number: 1835
# on file number: 1836
# on file number: 1837
# on file number: 1838
# on file number: 1839
# on file number: 1840
# on file number: 1841
# on file number: 1842
# on file number: 1843
# on file number: 1844
# on file number: 1845
# on file number: 1846
# on file number: 1847
# on file number: 1848
# on file number: 1849
# on file number: 1850
# on file number: 1851
# on file number: 1852
# on file number: 1853
# on file number: 1854
# on file number: 1855
# on file number: 1856
# on file number: 1857
# on file number: 1858
# on file number: 1859
# on file number: 1860
# on file number: 1861
# on file number: 1862
# on file number: 1863
# on file number: 1864
# on file number: 1865
# on file number: 1866
# on file number: 1867
# on file number: 1868
# on file number: 1869
# on file number: 1870
# on file number: 1871
# on file number: 1872
# on file number: 1873
# on file number: 1874
# on file number: 1875
# on file number: 1876
# on file number: 1877
# on file number: 1878
# on file number: 1879
# on file number: 1880
# on file number: 1881
# on file number: 1882
# on file number: 1883
# on file number: 1884
# on file number: 1885
# on file number: 1886
# on file number: 1887
# on file number: 1888
# on file number: 1889
# on file number: 1890
# on file number: 1891
# on file number: 1892
# on file number: 1893
# on file number: 1894
# on file number: 1895
# on file number: 1896
# on file number: 1897
# on file number: 1898
# on file number: 1899
# on file number: 1900
# on file number: 1901
# on file number: 1902
# on file number: 1903
# on file number: 1904
# on file number: 1905
# on file number: 1906
# on file number: 1907
# on file number: 1908
# on file number: 1909
# on file number: 1910
# on file number: 1911
# on file number: 1912
# on file number: 1913
# on file number: 1914
# on file number: 1915
# on file number: 1916
# on file number: 1917
# on file number: 1918
# on file number: 1919
# on file number: 1920
# on file number: 1921
# on file number: 1922
# on file number: 1923
# on file number: 1924
# on file number: 1925
# on file number: 1926
# on file number: 1927
# on file number: 1928
# on file number: 1929
# on file number: 1930
# on file number: 1931
# on file number: 1932
# on file number: 1933
# on file number: 1934
# on file number: 1935
# on file number: 1936
# on file number: 1937
# on file number: 1938
# on file number: 1939
# on file number: 1940
# on file number: 1941
# on file number: 1942
# on file number: 1943
# on file number: 1944
# on file number: 1945
# on file number: 1946
# on file number: 1947
# on file number: 1948
# on file number: 1949
# on file number: 1950
# on file number: 1951
# on file number: 1952
# on file number: 1953
# on file number: 1954
# on file number: 1955
# on file number: 1956
# on file number: 1957
# on file number: 1958
# on file number: 1959
# on file number: 1960
# on file number: 1961
# on file number: 1962
# on file number: 1963
# on file number: 1964
# on file number: 1965
# on file number: 1966
# on file number: 1967
# on file number: 1968
# on file number: 1969
# on file number: 1970
# on file number: 1971
# on file number: 1972
# on file number: 1973
# on file number: 1974
# on file number: 1975
# on file number: 1976
# on file number: 1977
# on file number: 1978
# on file number: 1979
# on file number: 1980
# on file number: 1981
# on file number: 1982
# on file number: 1983
# on file number: 1984
# on file number: 1985
# on file number: 1986
# on file number: 1987
# on file number: 1988
# on file number: 1989
# on file number: 1990
# on file number: 1991
# on file number: 1992
# on file number: 1993
# on file number: 1994
# on file number: 1995
# on file number: 1996
# on file number: 1997
# on file number: 1998
# on file number: 1999
# on file number: 2000
# on file number: 2001
# on file number: 2002
# on file number: 2003
# on file number: 2004
# on file number: 2005
# on file number: 2006
# on file number: 2007
# on file number: 2008
# on file number: 2009
# on file number: 2010
# on file number: 2011
# on file number: 2012
# on file number: 2013
# on file number: 2014
# on file number: 2015
# on file number: 2016
# on file number: 2017
# on file number: 2018
# on file number: 2019
# on file number: 2020
# on file number: 2021
# on file number: 2022
# on file number: 2023
# on file number: 2024
# on file number: 2025
# on file number: 2026
# on file number: 2027
# on file number: 2028
# on file number: 2029
# on file number: 2030
# on file number: 2031
# on file number: 2032
# on file number: 2033
# on file number: 2034
# on file number: 2035
# on file number: 2036
# on file number: 2037
# on file number: 2038
# on file number: 2039
# on file number: 2040
# on file number: 2041
# on file number: 2042
# on file number: 2043
# on file number: 2044
# on file number: 2045
# on file number: 2046
# on file number: 2047
# on file number: 2048
# on file number: 2049
# on file number: 2050
# on file number: 2051
# on file number: 2052
# on file number: 2053
# on file number: 2054
# on file number: 2055
# on file number: 2056
# on file number: 2057
# on file number: 2058
# on file number: 2059
# on file number: 2060
# on file number: 2061
# on file number: 2062
# on file number: 2063
# on file number: 2064
# on file number: 2065
# on file number: 2066
# on file number: 2067
# on file number: 2068
# on file number: 2069
# on file number: 2070
# on file number: 2071
# on file number: 2072
# on file number: 2073
# on file number: 2074
# on file number: 2075
# on file number: 2076
# on file number: 2077
# on file number: 2078
# on file number: 2079
# on file number: 2080
# on file number: 2081
# on file number: 2082
# on file number: 2083
# on file number: 2084
# on file number: 2085
# on file number: 2086
# on file number: 2087
# on file number: 2088
# on file number: 2089
# on file number: 2090
# on file number: 2091
# on file number: 2092
# on file number: 2093
# on file number: 2094
# on file number: 2095
# on file number: 2096
# on file number: 2097
# on file number: 2098
# on file number: 2099
# on file number: 2100
# on file number: 2101
# on file number: 2102
# on file number: 2103
# on file number: 2104
# on file number: 2105
# on file number: 2106
# on file number: 2107
# on file number: 2108
# on file number: 2109
# on file number: 2110
# on file number: 2111
# on file number: 2112
# on file number: 2113
# on file number: 2114
# on file number: 2115
# on file number: 2116
# on file number: 2117
# on file number: 2118
# on file number: 2119
# on file number: 2120
# on file number: 2121
# on file number: 2122
# on file number: 2123
# on file number: 2124
# on file number: 2125
# on file number: 2126
# on file number: 2127
# on file number: 2128
# on file number: 2129
# on file number: 2130
# on file number: 2131
# on file number: 2132
# on file number: 2133
# on file number: 2134
# on file number: 2135
# on file number: 2136
# on file number: 2137
# on file number: 2138
# on file number: 2139
# on file number: 2140
# on file number: 2141
# on file number: 2142
# on file number: 2143
# on file number: 2144
# on file number: 2145
# on file number: 2146
# on file number: 2147
# on file number: 2148
# on file number: 2149
# on file number: 2150
# on file number: 2151
# on file number: 2152
# on file number: 2153
# on file number: 2154
# on file number: 2155
# on file number: 2156
# on file number: 2157
# on file number: 2158
# on file number: 2159
# on file number: 2160
# on file number: 2161
# on file number: 2162
# on file number: 2163
# on file number: 2164
# on file number: 2165
# on file number: 2166
# on file number: 2167
# on file number: 2168
# on file number: 2169
# on file number: 2170
# on file number: 2171
# on file number: 2172
# on file number: 2173
# on file number: 2174
# on file number: 2175
# on file number: 2176
# on file number: 2177
# on file number: 2178
# on file number: 2179
# on file number: 2180
# on file number: 2181
# on file number: 2182
# on file number: 2183
# on file number: 2184
# on file number: 2185
# on file number: 2186
# on file number: 2187
# on file number: 2188
# on file number: 2189
# on file number: 2190
# on file number: 2191
# on file number: 2192
# on file number: 2193
# on file number: 2194
# on file number: 2195
# on file number: 2196
# on file number: 2197
# on file number: 2198
# on file number: 2199
# on file number: 2200
# on file number: 2201
# on file number: 2202
# on file number: 2203
# on file number: 2204
# on file number: 2205
# on file number: 2206
# on file number: 2207
# on file number: 2208
# on file number: 2209
# on file number: 2210
# on file number: 2211
# on file number: 2212
# on file number: 2213
# on file number: 2214
# on file number: 2215
# on file number: 2216
# on file number: 2217
# on file number: 2218
# on file number: 2219
# on file number: 2220
# on file number: 2221
# on file number: 2222
# on file number: 2223
# on file number: 2224
# on file number: 2225
# on file number: 2226
# on file number: 2227
# on file number: 2228
# on file number: 2229
# on file number: 2230
# on file number: 2231
# on file number: 2232
# on file number: 2233
# on file number: 2234
# on file number: 2235
# on file number: 2236
# on file number: 2237
# on file number: 2238
# on file number: 2239
# on file number: 2240
# on file number: 2241
# on file number: 2242
# on file number: 2243
# on file number: 2244
# on file number: 2245
# on file number: 2246
# on file number: 2247
# on file number: 2248
# on file number: 2249
# on file number: 2250
# on file number: 2251
# on file number: 2252
# on file number: 2253
# on file number: 2254
# on file number: 2255
# on file number: 2256
# on file number: 2257
# on file number: 2258
# on file number: 2259
# on file number: 2260
# on file number: 2261
# on file number: 2262
# on file number: 2263
# on file number: 2264
# on file number: 2265
# on file number: 2266
# on file number: 2267
# on file number: 2268
# on file number: 2269
# on file number: 2270
# on file number: 2271
# on file number: 2272
# on file number: 2273
# on file number: 2274
# on file number: 2275
# on file number: 2276
# on file number: 2277
# on file number: 2278
# on file number: 2279
# on file number: 2280
# on file number: 2281
# on file number: 2282
# on file number: 2283
# on file number: 2284
# on file number: 2285
# on file number: 2286
# on file number: 2287
# on file number: 2288
# on file number: 2289
# on file number: 2290
# on file number: 2291
# on file number: 2292
# on file number: 2293
# on file number: 2294
# on file number: 2295
# on file number: 2296
# on file number: 2297
# on file number: 2298
# on file number: 2299
# on file number: 2300
# on file number: 2301
# on file number: 2302
# on file number: 2303
# on file number: 2304
# on file number: 2305
# on file number: 2306
# on file number: 2307
# on file number: 2308
# on file number: 2309
# on file number: 2310
# on file number: 2311
# on file number: 2312
# on file number: 2313
# on file number: 2314
# on file number: 2315
# on file number: 2316
# on file number: 2317
# on file number: 2318
# on file number: 2319
# on file number: 2320
# on file number: 2321
# on file number: 2322
# on file number: 2323
# on file number: 2324
# on file number: 2325
# on file number: 2326
# on file number: 2327
# on file number: 2328
# on file number: 2329
# on file number: 2330
# on file number: 2331
# on file number: 2332
# on file number: 2333
# on file number: 2334
# on file number: 2335
# on file number: 2336
# ...
# on file number: 12382
# on file number: 12383
# on file number: 12384
# on file number: 12385
# on file number: 12386
# on file number: 12387
# on file number: 12388
# on file number: 12389
# on file number: 12390
# on file number: 12391
# on file number: 12392
# on file number: 12393
# on file number: 12394
# on file number: 12395
# on file number: 12396
# on file number: 12397
# on file number: 12398
# on file number: 12399
# on file number: 12400
# on file number: 12401
# on file number: 12402
# on file number: 12403
# on file number: 12404
# on file number: 12405
# on file number: 12406
# on file number: 12407
# on file number: 12408
# on file number: 12409
# on file number: 12410
# on file number: 12411
# on file number: 12412
# on file number: 12413
# on file number: 12414
# on file number: 12415
# on file number: 12416
# on file number: 12417
# on file number: 12418
# on file number: 12419
# on file number: 12420
# on file number: 12421
# on file number: 12422
# on file number: 12423
# on file number: 12424
# on file number: 12425
# on file number: 12426
# on file number: 12427
# on file number: 12428
# on file number: 12429
# on file number: 12430
# on file number: 12431
# on file number: 12432
# on file number: 12433
# on file number: 12434
# on file number: 12435
# on file number: 12436
# on file number: 12437
# on file number: 12438
# on file number: 12439
# on file number: 12440
# on file number: 12441
# on file number: 12442
# on file number: 12443
# on file number: 12444
# on file number: 12445
# on file number: 12446
# on file number: 12447
# on file number: 12448
# on file number: 12449
# on file number: 12450
# on file number: 12451
# on file number: 12452
# on file number: 12453
# on file number: 12454
# on file number: 12455
# on file number: 12456
# on file number: 12457
# on file number: 12458
# on file number: 12459
# on file number: 12460
# on file number: 12461
# on file number: 12462
# on file number: 12463
# on file number: 12464
# on file number: 12465
# on file number: 12466
# on file number: 12467
# on file number: 12468
# on file number: 12469
# on file number: 12470
# on file number: 12471
# on file number: 12472
# on file number: 12473
# on file number: 12474
# on file number: 12475
# on file number: 12476
# on file number: 12477
# on file number: 12478
# on file number: 12479
# on file number: 12480
# on file number: 12481
# on file number: 12482
# on file number: 12483
# on file number: 12484
# on file number: 12485
# on file number: 12486
# on file number: 12487
# on file number: 12488
# on file number: 12489
# on file number: 12490
# on file number: 12491
# on file number: 12492
# on file number: 12493
# on file number: 12494
# on file number: 12495
# on file number: 12496
# on file number: 12497
# on file number: 12498
# on file number: 12499
# on file number: 12500
# on file number: 12501
# on file number: 12502
# on file number: 12503
# on file number: 12504
# on file number: 12505
# on file number: 12506
# on file number: 12507
# on file number: 12508
# on file number: 12509
# on file number: 12510
# on file number: 12511
# on file number: 12512
# on file number: 12513
# on file number: 12514
# on file number: 12515
# on file number: 12516
# on file number: 12517
# on file number: 12518
# on file number: 12519
# on file number: 12520
# on file number: 12521
# on file number: 12522
# on file number: 12523
# on file number: 12524
# on file number: 12525
# on file number: 12526
# on file number: 12527
# on file number: 12528
# on file number: 12529
# on file number: 12530
# on file number: 12531
# on file number: 12532
# on file number: 12533
# on file number: 12534
# on file number: 12535
# on file number: 12536
# on file number: 12537
# on file number: 12538
# on file number: 12539
# on file number: 12540
# on file number: 12541
# on file number: 12542
# on file number: 12543
# on file number: 12544
# on file number: 12545
# on file number: 12546
# on file number: 12547
# on file number: 12548
# on file number: 12549
# on file number: 12550
# on file number: 12551
# on file number: 12552
# on file number: 12553
# on file number: 12554
# on file number: 12555
# on file number: 12556
# on file number: 12557
# on file number: 12558
# on file number: 12559
# on file number: 12560
# on file number: 12561
# on file number: 12562
# on file number: 12563
# on file number: 12564
# on file number: 12565
# on file number: 12566
# on file number: 12567
# on file number: 12568
# on file number: 12569
# on file number: 12570
# on file number: 12571
# on file number: 12572
# on file number: 12573
# on file number: 12574
# on file number: 12575
# on file number: 12576
# on file number: 12577
# on file number: 12578
# on file number: 12579
# on file number: 12580
# on file number: 12581
# on file number: 12582
# on file number: 12583
# on file number: 12584
# on file number: 12585
# on file number: 12586
# on file number: 12587
# on file number: 12588
# on file number: 12589
# on file number: 12590
# on file number: 12591
# on file number: 12592
# on file number: 12593
# on file number: 12594
# on file number: 12595
# on file number: 12596
# on file number: 12597
# on file number: 12598
# on file number: 12599
# on file number: 12600
# on file number: 12601
# on file number: 12602
# on file number: 12603
# on file number: 12604
# on file number: 12605
# on file number: 12606
# on file number: 12607
# on file number: 12608
# on file number: 12609
# on file number: 12610
# on file number: 12611
# on file number: 12612
# on file number: 12613
# on file number: 12614
# on file number: 12615
# on file number: 12616
# on file number: 12617
# on file number: 12618
# on file number: 12619
# on file number: 12620
# on file number: 12621
# on file number: 12622
# on file number: 12623
# on file number: 12624
# on file number: 12625
# on file number: 12626
# on file number: 12627
# on file number: 12628
# on file number: 12629
# on file number: 12630
# on file number: 12631
# on file number: 12632
# on file number: 12633
# on file number: 12634
# on file number: 12635
# on file number: 12636
# on file number: 12637
# on file number: 12638
# on file number: 12639
# on file number: 12640
# on file number: 12641
# on file number: 12642
# on file number: 12643
# on file number: 12644
# on file number: 12645
# on file number: 12646
# on file number: 12647
# on file number: 12648
# on file number: 12649
# on file number: 12650
# on file number: 12651
# on file number: 12652
# on file number: 12653
# on file number: 12654
# on file number: 12655
# on file number: 12656
# on file number: 12657
# on file number: 12658
# on file number: 12659
# on file number: 12660
# on file number: 12661
# on file number: 12662
# on file number: 12663
# on file number: 12664
# on file number: 12665
# on file number: 12666
# on file number: 12667
# on file number: 12668
# on file number: 12669
# on file number: 12670
# on file number: 12671
# on file number: 12672
# on file number: 12673
# on file number: 12674
# on file number: 12675
# on file number: 12676
# on file number: 12677
# on file number: 12678
# on file number: 12679
# on file number: 12680
# on file number: 12681
# on file number: 12682
# on file number: 12683
# on file number: 12684
# on file number: 12685
# on file number: 12686
# on file number: 12687
# on file number: 12688
# on file number: 12689
# on file number: 12690
# on file number: 12691
# on file number: 12692
# on file number: 12693
# on file number: 12694
# on file number: 12695
# on file number: 12696
# on file number: 12697
# on file number: 12698
# on file number: 12699
# on file number: 12700
# on file number: 12701
# on file number: 12702
# on file number: 12703
# on file number: 12704
# on file number: 12705
# on file number: 12706
# on file number: 12707
# on file number: 12708
# on file number: 12709
# on file number: 12710
# on file number: 12711
# on file number: 12712
# on file number: 12713
# on file number: 12714
# on file number: 12715
# on file number: 12716
# on file number: 12717
# on file number: 12718
# on file number: 12719
# on file number: 12720
# on file number: 12721
# on file number: 12722
# on file number: 12723
# on file number: 12724
# on file number: 12725
# on file number: 12726
# on file number: 12727
# on file number: 12728
# on file number: 12729
# on file number: 12730
# on file number: 12731
# on file number: 12732
# on file number: 12733
# on file number: 12734
# on file number: 12735
# on file number: 12736
# on file number: 12737
# on file number: 12738
# on file number: 12739
# on file number: 12740
# on file number: 12741
# on file number: 12742
# on file number: 12743
# on file number: 12744
# on file number: 12745
# on file number: 12746
# on file number: 12747
# on file number: 12748
# on file number: 12749
# on file number: 12750
# on file number: 12751
# on file number: 12752
# on file number: 12753
# on file number: 12754
# on file number: 12755
# on file number: 12756
# on file number: 12757
# on file number: 12758
# on file number: 12759
# on file number: 12760
# on file number: 12761
# on file number: 12762
# on file number: 12763
# on file number: 12764
# on file number: 12765
# on file number: 12766
# on file number: 12767
# on file number: 12768
# on file number: 12769
# on file number: 12770
# on file number: 12771
# on file number: 12772
# on file number: 12773
# on file number: 12774
# on file number: 12775
# on file number: 12776
# on file number: 12777
# on file number: 12778
# on file number: 12779
# on file number: 12780
# on file number: 12781
# on file number: 12782
# on file number: 12783
# on file number: 12784
# on file number: 12785
# on file number: 12786
# on file number: 12787
# on file number: 12788
# on file number: 12789
# on file number: 12790
# on file number: 12791
# on file number: 12792
# on file number: 12793
# on file number: 12794
# on file number: 12795
# on file number: 12796
# on file number: 12797
# on file number: 12798
# on file number: 12799
# on file number: 12800
# on file number: 12801
# on file number: 12802
# on file number: 12803
# on file number: 12804
# on file number: 12805
# on file number: 12806
# on file number: 12807
# on file number: 12808
# on file number: 12809
# on file number: 12810
# on file number: 12811
# on file number: 12812
# on file number: 12813
# on file number: 12814
# on file number: 12815
# on file number: 12816
# on file number: 12817
# on file number: 12818
# on file number: 12819
# on file number: 12820
# on file number: 12821
# on file number: 12822
# on file number: 12823
# on file number: 12824
# on file number: 12825
# on file number: 12826
# on file number: 12827
# on file number: 12828
# on file number: 12829
# on file number: 12830
# on file number: 12831
# on file number: 12832
# on file number: 12833
# on file number: 12834
# on file number: 12835
# on file number: 12836
# on file number: 12837
# on file number: 12838
# on file number: 12839
# on file number: 12840
# on file number: 12841
# on file number: 12842
# on file number: 12843
# on file number: 12844
# on file number: 12845
# on file number: 12846
# on file number: 12847
# on file number: 12848
# on file number: 12849
# on file number: 12850
# on file number: 12851
# on file number: 12852
# on file number: 12853
# on file number: 12854
# on file number: 12855
# on file number: 12856
# on file number: 12857
# on file number: 12858
# on file number: 12859
# on file number: 12860
# on file number: 12861
# on file number: 12862
# on file number: 12863
# on file number: 12864
# on file number: 12865
# on file number: 12866
# on file number: 12867
# on file number: 12868
# on file number: 12869
# on file number: 12870
# on file number: 12871
# on file number: 12872
# on file number: 12873
# on file number: 12874
# on file number: 12875
# on file number: 12876
# on file number: 12877
# on file number: 12878
# on file number: 12879
# on file number: 12880
# on file number: 12881
# on file number: 12882
# on file number: 12883
# on file number: 12884
# on file number: 12885
# on file number: 12886
# on file number: 12887
# on file number: 12888
# on file number: 12889
# on file number: 12890
# on file number: 12891
# on file number: 12892
# on file number: 12893
# on file number: 12894
# on file number: 12895
# on file number: 12896
# on file number: 12897
# on file number: 12898
# on file number: 12899
# on file number: 12900
# on file number: 12901
# on file number: 12902
# on file number: 12903
# on file number: 12904
# on file number: 12905
# on file number: 12906
# on file number: 12907
# on file number: 12908
# on file number: 12909
# on file number: 12910
# on file number: 12911
# on file number: 12912
# on file number: 12913
# on file number: 12914
# on file number: 12915
# on file number: 12916
# on file number: 12917
# on file number: 12918
# on file number: 12919
# on file number: 12920
# on file number: 12921
# on file number: 12922
# on file number: 12923
# on file number: 12924
# on file number: 12925
# on file number: 12926
# on file number: 12927
# on file number: 12928
# on file number: 12929
# on file number: 12930
# on file number: 12931
# on file number: 12932
# on file number: 12933
# on file number: 12934
# on file number: 12935
# on file number: 12936
# on file number: 12937
# on file number: 12938
# on file number: 12939
# on file number: 12940
# on file number: 12941
# on file number: 12942
# on file number: 12943
# on file number: 12944
# on file number: 12945
# on file number: 12946
# on file number: 12947
# on file number: 12948
# on file number: 12949
# on file number: 12950
# on file number: 12951
# on file number: 12952
# on file number: 12953
# on file number: 12954
# on file number: 12955
# on file number: 12956
# on file number: 12957
# on file number: 12958
# on file number: 12959
# on file number: 12960
# on file number: 12961
# on file number: 12962
# on file number: 12963
# on file number: 12964
# on file number: 12965
# on file number: 12966
# on file number: 12967
# on file number: 12968
# on file number: 12969
# on file number: 12970
# on file number: 12971
# on file number: 12972
# on file number: 12973
# on file number: 12974
# on file number: 12975
# on file number: 12976
# on file number: 12977
# on file number: 12978
# on file number: 12979
# on file number: 12980
# on file number: 12981
# on file number: 12982
# on file number: 12983
# on file number: 12984
# on file number: 12985
# on file number: 12986
# on file number: 12987
# on file number: 12988
# on file number: 12989
# on file number: 12990
# on file number: 12991
# on file number: 12992
# on file number: 12993
# on file number: 12994
# on file number: 12995
# on file number: 12996
# on file number: 12997
# on file number: 12998
# on file number: 12999
# on file number: 13000
# on file number: 13001
# on file number: 13002
# on file number: 13003
# on file number: 13004
# on file number: 13005
# on file number: 13006
# on file number: 13007
# on file number: 13008
# on file number: 13009
# on file number: 13010
# on file number: 13011
# on file number: 13012
# on file number: 13013
# on file number: 13014
# on file number: 13015
# on file number: 13016
# on file number: 13017
# on file number: 13018
# on file number: 13019
# on file number: 13020
# on file number: 13021
# on file number: 13022
# on file number: 13023
# on file number: 13024
# on file number: 13025
# on file number: 13026
# on file number: 13027
# on file number: 13028
# on file number: 13029
# on file number: 13030
# on file number: 13031
# on file number: 13032
# on file number: 13033
# on file number: 13034
# on file number: 13035
# on file number: 13036
# on file number: 13037
# on file number: 13038
# on file number: 13039
# on file number: 13040
# on file number: 13041
# on file number: 13042
# on file number: 13043
# on file number: 13044
# on file number: 13045
# on file number: 13046
# on file number: 13047
# on file number: 13048
# on file number: 13049
# on file number: 13050
# on file number: 13051
# on file number: 13052
# on file number: 13053
# on file number: 13054
# on file number: 13055
# on file number: 13056
# on file number: 13057
# on file number: 13058
# on file number: 13059
# on file number: 13060
# on file number: 13061
# on file number: 13062
# on file number: 13063
# on file number: 13064
# on file number: 13065
# on file number: 13066
# on file number: 13067
# on file number: 13068
# on file number: 13069
# on file number: 13070
# on file number: 13071
# on file number: 13072
# on file number: 13073
# on file number: 13074
# on file number: 13075
# on file number: 13076
# on file number: 13077
# on file number: 13078
# on file number: 13079
# on file number: 13080
# on file number: 13081
# on file number: 13082
# on file number: 13083
# on file number: 13084
# on file number: 13085
# on file number: 13086
# on file number: 13087
# on file number: 13088
# on file number: 13089
# on file number: 13090
# on file number: 13091
# on file number: 13092
# on file number: 13093
# on file number: 13094
# on file number: 13095
# on file number: 13096
# on file number: 13097
# on file number: 13098
# on file number: 13099
# on file number: 13100
# on file number: 13101
# on file number: 13102
# on file number: 13103
# on file number: 13104
# on file number: 13105
# on file number: 13106
# on file number: 13107
# on file number: 13108

# %%
import pickle

# %%
len(sentences)
# Out:
# 143709

# %%
all_ner_tags
# Out:
# {'B-CARDINAL',
#  'B-DATE',
#  'B-EVENT',
#  'B-FAC',
#  'B-GPE',
#  'B-LANGUAGE',
#  'B-LAW',
#  'B-LOC',
#  'B-MONEY',
#  'B-NORP',
#  'B-ORDINAL',
#  'B-ORG',
#  'B-PERCENT',
#  'B-PERSON',
#  'B-PRODUCT',
#  'B-QUANTITY',
#  'B-TIME',
#  'B-WORK_OF_ART',
#  'I-CARDINAL',
#  'I-DATE',
#  'I-EVENT',
#  'I-FAC',
#  'I-GPE',
#  'I-LANGUAGE',
#  'I-LAW',
#  'I-LOC',
#  'I-MONEY',
#  'I-NORP',
#  'I-ORDINAL',
#  'I-ORG',
#  'I-PERCENT',
#  'I-PERSON',
#  'I-PRODUCT',
#  'I-QUANTITY',
#  'I-TIME',
#  'I-WORK_OF_ART',
#  'O'}

# %%
#Serialize our modified dataset
#with open("modified_dataset.pkl", "wb") as output:
#    pickle.dump(sentences, output, pickle.HIGHEST_PROTOCOL)

# %%
#IMPORTANT, I have already done everything above and saved it as a
#serialized file that can be opened quickly, so just do this instead

with open("modified_dataset.pkl", "rb") as input:
    modified_dataset = pickle.load(input)

# %%
len(modified_dataset)
# Out:
# 143709

# %%
test_sentence = modified_dataset[0]
test_sentence
# Out:
# [('In', 'IN', 'O'),
#  ('the', 'DT', 'B-DATE'),
#  ('summer', 'NN', 'I-DATE'),
#  ('of', 'IN', 'I-DATE'),
#  ('2005', 'CD', 'I-DATE'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'O'),
#  ('picture', 'NN', 'O'),
#  ('that', 'WDT', 'O'),
#  ('people', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('long', 'RB', 'O'),
#  ('been', 'VBN', 'O'),
#  ('looking', 'VBG', 'O'),
#  ('forward', 'RB', 'O'),
#  ('to', 'TO', 'O'),
#  ('started', 'VBD', 'O'),
#  ('emerging', 'VBG', 'O'),
#  ('with', 'IN', 'O'),
#  ('frequency', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('various', 'JJ', 'O'),
#  ('major', 'JJ', 'O'),
#  ('Hong', 'NNP', 'B-GPE'),
#  ('Kong', 'NNP', 'I-GPE'),
#  ('media', 'NNS', 'O'),
#  ('.', '.', 'O')]

# %%
#assumed to be in the environment of the function that 
#generates the feature dictionary for task 3
number_gazetteer = set([
	"one", "two", "three", "four", "five", "six", "seven", "eight",
	"nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
	"sixteen", "seventeen", "eighteen", "nineteen", "twenty"
	])

#Python sets are implemented as hash tables so lookup is always around O(1)
#even for large sets

ordinal_gazetteer = set([
	"first", "second", "third", "fourth", "fifth", "sixth", "seventh",
	"eigth", "ninth", "tenth", "eleventh", "twelth", "thirteenth",
	"fourteenth", "fifteenth", "sixteenth", "seventeenth", "eighteenth",
	"nineteenth", "twentieth", "thirtieth", "fourtieth", "fiftieth", 
	"sixtieth", "seventieth", "eightieth", "ninetieth", "hundreth", "thousandth",
	"millionth"
])

#date_gazetteer = set([
#	"day", "year", "month", "holi"
#	])

# %%
#generate a feature dictionary for the word at index i in the sentence
def gen_feature_dict_task3(sentence, i):
    
	#token = sentence[i][0]
	#pos_tag = sentence[i][1]

	def gen_features(index, relative_str):
		
		return {
			relative_str + "word.lower()": sentence[index][0].lower(),
			relative_str + "word_prefix": sentence[index][0][:3],
			relative_str + "word_suffix": sentence[index][0][-3:],
			relative_str + "postag": sentence[index][1],
			#relative_str + "postag_prefix": sentence[index][1][:3],
			relative_str + "istitle": sentence[index][0].istitle(),
			
			#don't think this will be very useful
			relative_str + "isupper": sentence[index][0].isupper(),
			relative_str + "in_num_gaz": sentence[index][0].lower() in number_gazetteer,
			relative_str + "in_ord_gaz": sentence[index][0].lower() in ordinal_gazetteer,
			#relative_str + "contains-digit": any(char.isdigit() for char in sentence[index][0]), 
			relative_str + "contains-day": "day" in sentence[index][0]
		}

	features = gen_features(i, "")

	#there is at least 1 word behind
	if i > 0:
		features.update(gen_features(i - 1, "-1:"))

	#there are at least 2 words behind
	if i > 1:
		features.update(gen_features(i - 2, "-2:"))

	#there is at least 1 word ahead
	if i < len(sentence) - 1:
		features.update(gen_features(i + 1, "+1:"))
	
	#there are at least 2 words ahead
	if i < len(sentence) - 2:
		features.update(gen_features(i + 2, "+2:"))
	
	return features

# %%
#generate a list of feature dictionaries for each word in the sentence
def gen_task3_features(sentence):
	return [gen_feature_dict_task3(sentence, i) for i in range(len(sentence))]

#helper functions
def sent2labels(sentence):
	return [label for _, _, label in sentence] 
def sent2tokens(sent):
	return [token for token, _, _ in sentence]

# %%
test_dicts = [gen_feature_dict(test_sentence, i) for i in range(len(test_sentence))]

# %%
def train_crf_model(X_train, Y_train, max_iter, is_verbose = False):
	
	crf = sklearn_crfsuit.CRF(
		
		#all these are hyperparameters that can be tuned later
		algorithm = "lbfgs",
		c1 = 0.1,
		c2 = 0.1,
		
		max_iterations = max_iter,
		all_possible_transitions=False,
		verbose = is_verbose
	)
	
	crf.fit(X_train, Y_train)
	return crf

# %%
from random import shuffle
from copy import deepcopy

# %%
#use if you want to do training and testing
def random_split(sentences):
	
	shuffle(sentences)
	#change this to whatever ratio you want it to be
	train_size = int((0.9 * len(sentences)))
	test_size = len(sentences) - train_size
	
	return sentences[:train_size], sentences[-test_size:]

# %%
def train_model(sentences, is_verbose = False):
	
	#feature dictionaries for each word in a sentence
	feature_lists = [gen_task3_features(sent) for sent in sentences]
	
	#NER labels for each word in a sentence
	label_lists = [sent2labels(sent) for sent in sentences]
	
	crf = sklearn_crfsuite.CRF(
		
		#all these are hyperparameters that can be tuned later
		algorithm = "lbfgs",
		c1 = 0.1,
		c2 = 0.1,
		
		max_iterations = max_iter,
		all_possible_transitions=False,
		verbose = is_verbose
	)
	
	crf.fit(feature_lists, label_lists)
	
	labels = list(crf.classes_).remove('O')
	
	return crf

# %%
# %%time
crf = train_model(modified_dataset, True)
