# %%
import nltk

# %%
#the entire file contents is read in as a literal string containing new lines etc

f = open("STOPWORDS.txt")

stopwords = f.read()
f.close()

f = open("speech2015.txt")

speech2015 = f.read()
f.close()

f = open("speech2020.txt")

speech2020 = f.read()
f.close()

# %%
from bpe import Encoder

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE

# %%
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer2 = Tokenizer(BPE(unk_token="[UNK]"))

# %%
from tokenizers.trainers import BpeTrainer

trainer = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], vocab_size = 1000)
trainer2 = BpeTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"], vocab_size = 1000)

# %%
from tokenizers.pre_tokenizers import Whitespace

tokenizer.pre_tokenizer = Whitespace()
tokenizer2.pre_tokenizer = Whitespace()

# %%
tokenizer.train(["speech2015.txt"])

# %%
tokenizer2.train(["speech2020.txt"])

# %%
t1 = tokenizer.get_vocab()
sorted(t1, key = t1.get, reverse = True)
# Out:
# ['maximize',
#  'Retraining',
#  'Emeritus',
#  'Efficiency',
#  'Edinburgh',
#  'Dasgupta',
#  'Chancellor',
#  'Carlisle',
#  'Bioinformatics',
#  'ARCHER2',
#  'exceptionally',
#  'differences',
#  'difficult',
#  'collectively',
#  'Negotiations',
#  'Authority',
#  'entrepreneurs',
#  'unemployment',
#  'squeeze',
#  'Headteachers',
#  'implementing',
#  'introduce',
#  'decisions',
#  'participation',
#  'particular',
#  'pollinators',
#  'points',
#  'possible',
#  'recognised',
#  'recruit',
#  'sympathies',
#  'carriers',
#  'calibrated',
#  'calculations',
#  'quarterly',
#  'measures',
#  'mechanism',
#  'compromise',
#  'compounding',
#  'objective',
#  'foreseeable',
#  'ultimate',
#  'expense',
#  'expert',
#  'terminals',
#  'unbroken',
#  'unfairness',
#  'tragedy',
#  'contribution',
#  'opposite',
#  'became',
#  'earnings',
#  'proposals',
#  'producers',
#  'property',
#  'immediately',
#  'improved',
#  'imminent',
#  'improve',
#  'allocating',
#  'subjects',
# ...

# %%
t2 = tokenizer2.get_vocab() 
sorted(t2, key = t2.get, reverse = True)
# Out:
# ['pulsars',
#  'Wolverhampton',
#  'Llanymynech',
#  'Jocelyn',
#  'Ineffective',
#  'Immigration',
#  'Hodgkin',
#  'Football',
#  'European',
#  'BUSINESS',
#  'Brownfield',
#  'Birmingham',
#  'Bromsgrove',
#  'struggle',
#  'motorbikes',
#  'despite',
#  'Structures',
#  'Shakespeare',
#  'Nottingham',
#  'Anatomy',
#  'symptoms',
#  'symbolising',
#  'Responsibility',
#  'certainly',
#  'Contributory',
#  'physically',
#  'Executive',
#  'Christmas',
#  'assistance',
#  'cyclical',
#  'backdrop',
#  'appointments',
#  'Unclogging',
#  'Committee',
#  'maintaining',
#  'fossil',
#  'restaurants',
#  'surgery',
#  '1980s',
#  'temporarily',
#  'consistent',
#  'officials',
#  'quicker',
#  'distilleries',
#  'discussions',
#  'discovery',
#  'distributed',
#  'discourage',
#  'Interruption',
#  'Institute',
#  'principles',
#  'obstruction',
#  'embassies',
#  'respected',
#  'landmarks',
#  'highlighted',
#  'features',
#  'manufacturers',
#  'buffer',
#  'preventing',
# ...
